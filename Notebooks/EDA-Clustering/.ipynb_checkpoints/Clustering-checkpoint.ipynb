# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Crop_Recommendation.csv")
features = ['Nitrogen', 'Phosphorus','Potassium', 'Temperature', 'Humidity', 'pH_Value', 'Rainfall']
columns = [(feature, 'mean') for feature in features]
means_df = df.groupby("Crop").describe()[columns]
means_df
# Out:
#             Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                 mean       mean      mean        mean       mean      mean
# Crop
# Apple          20.80     134.22    199.89   22.630942  92.333383  5.929663
# Banana        100.23      82.01     50.05   27.376798  80.358123  5.983893
# Blackgram      40.02      67.47     19.24   29.973340  65.118426  7.133952
# ChickPea       40.09      67.79     79.92   18.872847  16.860439  7.336957
# Coconut        21.98      16.93     30.59   27.409892  94.844272  5.976562
# Coffee        101.20      28.74     29.94   25.540477  58.869846  6.790308
# Cotton        117.77      46.24     19.56   23.988958  79.843474  6.912675
# Grapes         23.18     132.53    200.11   23.849575  81.875228  6.025937
# Jute           78.40      46.86     39.99   24.958376  79.639864  6.732778
# KidneyBeans    20.75      67.54     20.05   20.115085  21.605357  5.749411
# Lentil         18.77      68.36     19.41   24.509052  64.804785  6.927932
# Maize          77.76      48.44     19.79   22.389204  65.092249  6.245190
# Mango          20.07      27.18     29.92   31.208770  50.156573  5.766373
# MothBeans      21.44      48.01     20.23   28.194920  53.160418  6.831174
# MungBean       20.99      47.28     19.87   28.525775  85.499975  6.723957
# Muskmelon     100.32      17.72     50.08   28.663066  92.342802  6.358805
# Orange         19.58      16.55     10.01   22.765725  92.170209  7.016957
# Papaya         49.88      59.05     50.04   33.723859  92.403388  6.741442
# PigeonPeas     20.73      67.73     20.29   27.741762  48.061633  5.794175
# Pomegranate    18.87      18.75     40.21   21.837842  90.125504  6.429172
# Rice           79.89      47.58     39.87   23.689332  82.272822  6.425471
# Watermelon     99.42      17.00     50.22   25.591767  85.160375  6.495778
#
#                Rainfall
#                    mean
# Crop
# Apple        112.654779
# Banana       104.626980
# Blackgram     67.884151
# ChickPea      80.058977
# Coconut      175.686646
# Coffee       158.066295
# Cotton        80.398043
# Grapes        69.611829
# Jute         174.792798
# KidneyBeans  105.919778
# Lentil        45.680454
# Maize         84.766988
# Mango         94.704515
# MothBeans     51.198487
# MungBean      48.403601
# Muskmelon     24.689952
# Orange       110.474969
# Papaya       142.627839
# PigeonPeas   149.457564
# Pomegranate  107.528442
# Rice         236.181114
# Watermelon    50.786219

# %%
sorted_df = means_df.sort_values(by=("pH_Value", "mean"))
low_ph = sorted_df[sorted_df[("pH_Value", "mean")] < 6.03]
mid_ph = sorted_df[sorted_df[("pH_Value", "mean")] > 6.03]
mid_ph = mid_ph[mid_ph[("pH_Value","mean")] < 6.7]
mid_high_ph = sorted_df[sorted_df[("pH_Value", "mean")] > 6.7]
high_ph = mid_high_ph[sorted_df[("pH_Value", "mean")] > 6.9]
mid_high_ph = mid_high_ph[sorted_df[("pH_Value", "mean")] < 6.9]
ph_dfs = [low_ph,mid_ph,mid_high_ph, high_ph]
# Out:
# <ipython-input-4-785098d7f8f4>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_ph = mid_high_ph[sorted_df[("pH_Value", "mean")] > 6.9]
# <ipython-input-4-785098d7f8f4>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mid_high_ph = mid_high_ph[sorted_df[("pH_Value", "mean")] < 6.9]

# %%
sorted_ph_dfs = []
for ph_df in ph_dfs:
    sorted_ph_dfs.append(ph_df.sort_values(by=("Nitrogen", "mean")))
sorted_ph_dfs
# Out:
# [            Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                  mean       mean      mean        mean       mean      mean
#  Crop
#  Mango          20.07      27.18     29.92   31.208770  50.156573  5.766373
#  PigeonPeas     20.73      67.73     20.29   27.741762  48.061633  5.794175
#  KidneyBeans    20.75      67.54     20.05   20.115085  21.605357  5.749411
#  Apple          20.80     134.22    199.89   22.630942  92.333383  5.929663
#  Coconut        21.98      16.93     30.59   27.409892  94.844272  5.976562
#  Grapes         23.18     132.53    200.11   23.849575  81.875228  6.025937
#  Banana        100.23      82.01     50.05   27.376798  80.358123  5.983893
#
#                 Rainfall
#                     mean
#  Crop
#  Mango         94.704515
#  PigeonPeas   149.457564
#  KidneyBeans  105.919778
#  Apple        112.654779
#  Coconut      175.686646
#  Grapes        69.611829
#  Banana       104.626980  ,
#              Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                  mean       mean      mean        mean       mean      mean
#  Crop
#  Pomegranate    18.87      18.75     40.21   21.837842  90.125504  6.429172
#  Maize          77.76      48.44     19.79   22.389204  65.092249  6.245190
#  Rice           79.89      47.58     39.87   23.689332  82.272822  6.425471
#  Watermelon     99.42      17.00     50.22   25.591767  85.160375  6.495778
#  Muskmelon     100.32      17.72     50.08   28.663066  92.342802  6.358805
#
#                 Rainfall
#                     mean
#  Crop
#  Pomegranate  107.528442
#  Maize         84.766988
#  Rice         236.181114
#  Watermelon    50.786219
#  Muskmelon     24.689952  ,
#            Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                mean       mean      mean        mean       mean      mean
#  Crop
#  MungBean     20.99      47.28     19.87   28.525775  85.499975  6.723957
#  MothBeans    21.44      48.01     20.23   28.194920  53.160418  6.831174
#  Papaya       49.88      59.05     50.04   33.723859  92.403388  6.741442
#  Jute         78.40      46.86     39.99   24.958376  79.639864  6.732778
#  Coffee      101.20      28.74     29.94   25.540477  58.869846  6.790308
#
#               Rainfall
#                   mean
#  Crop
#  MungBean    48.403601
#  MothBeans   51.198487
#  Papaya     142.627839
#  Jute       174.792798
#  Coffee     158.066295  ,
#            Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                mean       mean      mean        mean       mean      mean
#  Crop
#  Lentil       18.77      68.36     19.41   24.509052  64.804785  6.927932
#  Orange       19.58      16.55     10.01   22.765725  92.170209  7.016957
#  Blackgram    40.02      67.47     19.24   29.973340  65.118426  7.133952
#  ChickPea     40.09      67.79     79.92   18.872847  16.860439  7.336957
#  Cotton      117.77      46.24     19.56   23.988958  79.843474  6.912675
#
#               Rainfall
#                   mean
#  Crop
#  Lentil      45.680454
#  Orange     110.474969
#  Blackgram   67.884151
#  ChickPea    80.058977
#  Cotton      80.398043  ]

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=11).fit_predict(means_df)
clusters = {}
for i in range(len(kmeans)):
    if kmeans[i] not in clusters:
        clusters[kmeans[i]] = [means_df.index[i]]
    else:
        clusters[kmeans[i]].append(means_df.index[i])
clusters
# Out:
# {2: ['Apple', 'Grapes'],
#  3: ['Banana', 'Cotton', 'Maize'],
#  6: ['Blackgram', 'Lentil', 'MothBeans', 'MungBean'],
#  0: ['ChickPea'],
#  10: ['Coconut'],
#  1: ['Coffee', 'Jute'],
#  5: ['KidneyBeans', 'PigeonPeas'],
#  4: ['Mango', 'Orange', 'Pomegranate'],
#  7: ['Muskmelon', 'Watermelon'],
#  8: ['Papaya'],
#  9: ['Rice']}

# %%
means_df[[idx in clusters[8] for idx in means_df.index]]
# Out:
#        Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#            mean       mean      mean        mean       mean      mean
# Crop
# Papaya    49.88      59.05     50.04   33.723859  92.403388  6.741442
#
#           Rainfall
#               mean
# Crop
# Papaya  142.627839

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=13).fit_predict(means_df)
clusters = {}
for i in range(len(kmeans)):
    if kmeans[i] not in clusters:
        clusters[kmeans[i]] = [means_df.index[i]]
    else:
        clusters[kmeans[i]].append(means_df.index[i])
clusters
# Out:
# {3: ['Apple', 'Grapes'],
#  12: ['Banana'],
#  5: ['Blackgram', 'Lentil', 'MothBeans', 'MungBean'],
#  1: ['ChickPea'],
#  10: ['Coconut'],
#  0: ['Coffee', 'Jute'],
#  4: ['Cotton', 'Maize'],
#  9: ['KidneyBeans', 'PigeonPeas'],
#  2: ['Mango'],
#  7: ['Muskmelon', 'Watermelon'],
#  11: ['Orange', 'Pomegranate'],
#  6: ['Papaya'],
#  8: ['Rice']}

# %%
means_df
# Out:
#             Nitrogen Phosphorus Potassium Temperature   Humidity  pH_Value  \
#                 mean       mean      mean        mean       mean      mean
# Crop
# Apple          20.80     134.22    199.89   22.630942  92.333383  5.929663
# Banana        100.23      82.01     50.05   27.376798  80.358123  5.983893
# Blackgram      40.02      67.47     19.24   29.973340  65.118426  7.133952
# ChickPea       40.09      67.79     79.92   18.872847  16.860439  7.336957
# Coconut        21.98      16.93     30.59   27.409892  94.844272  5.976562
# Coffee        101.20      28.74     29.94   25.540477  58.869846  6.790308
# Cotton        117.77      46.24     19.56   23.988958  79.843474  6.912675
# Grapes         23.18     132.53    200.11   23.849575  81.875228  6.025937
# Jute           78.40      46.86     39.99   24.958376  79.639864  6.732778
# KidneyBeans    20.75      67.54     20.05   20.115085  21.605357  5.749411
# Lentil         18.77      68.36     19.41   24.509052  64.804785  6.927932
# Maize          77.76      48.44     19.79   22.389204  65.092249  6.245190
# Mango          20.07      27.18     29.92   31.208770  50.156573  5.766373
# MothBeans      21.44      48.01     20.23   28.194920  53.160418  6.831174
# MungBean       20.99      47.28     19.87   28.525775  85.499975  6.723957
# Muskmelon     100.32      17.72     50.08   28.663066  92.342802  6.358805
# Orange         19.58      16.55     10.01   22.765725  92.170209  7.016957
# Papaya         49.88      59.05     50.04   33.723859  92.403388  6.741442
# PigeonPeas     20.73      67.73     20.29   27.741762  48.061633  5.794175
# Pomegranate    18.87      18.75     40.21   21.837842  90.125504  6.429172
# Rice           79.89      47.58     39.87   23.689332  82.272822  6.425471
# Watermelon     99.42      17.00     50.22   25.591767  85.160375  6.495778
#
#                Rainfall
#                    mean
# Crop
# Apple        112.654779
# Banana       104.626980
# Blackgram     67.884151
# ChickPea      80.058977
# Coconut      175.686646
# Coffee       158.066295
# Cotton        80.398043
# Grapes        69.611829
# Jute         174.792798
# KidneyBeans  105.919778
# Lentil        45.680454
# Maize         84.766988
# Mango         94.704515
# MothBeans     51.198487
# MungBean      48.403601
# Muskmelon     24.689952
# Orange       110.474969
# Papaya       142.627839
# PigeonPeas   149.457564
# Pomegranate  107.528442
# Rice         236.181114
# Watermelon    50.786219

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
count = 0
X = means_df.reset_index()
X.drop(["Crop"], axis=1, inplace=True)
cs = []
for k in np.arange(6,15):
    
    fig, ax = plt.subplots(figsize=(15,8))
    
    c = KMeans(n_clusters=k, random_state=0).fit_predict(X)
    cs.append(c)
    silhouette_avg = silhouette_score(X, c)
    sample_silhouette_values = silhouette_samples(X, c)
    y_lower=10
    for i in range(k):
        ith_cluster_silhouette_values = sample_silhouette_values[c == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / k)
        ax.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )
        ax.text(-0.03, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
        
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax.set_xlabel('Silhouette Score')
    ax.set_ylabel('Cluster')
    ax.set_title('Silhouette Plot for ' + str(k) + ' Clusters')
    
    ax.set_yticks([])
    
    count += 1
clusters = {}
c0 = cs[0]
for i in range(len(c0)):
    if c0[i] not in clusters:
        clusters[c0[i]] = [means_df.index[i]]
    else:
        clusters[c0[i]].append(means_df.index[i])
print(clusters)
# Out:
# C:\Users\dclutterbuck\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# {2: ['Apple', 'Grapes'], 1: ['Banana', 'Cotton', 'Maize'], 3: ['Blackgram', 'ChickPea', 'KidneyBeans', 'Lentil', 'Mango', 'MothBeans', 'MungBean'], 0: ['Coconut', 'Orange', 'Papaya', 'PigeonPeas', 'Pomegranate'], 5: ['Coffee', 'Jute', 'Rice'], 4: ['Muskmelon', 'Watermelon']}

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# 2     263.964248    Rice
# 3     242.864034    Rice
# 4     262.717340    Rice
# ...          ...     ...
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee
#
# [2200 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
y = df['Crop']
X = df.drop(columns = ['Crop'], axis = 1)
scaler = MinMaxScaler()
X_transformed = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=8, random_state = 0).fit_predict(X_transformed)
df_kmeans = df.copy()
df_kmeans["Cluster"] = kmeans
clusters = {}
for index, row in df_kmeans.iterrows():

    if row.Cluster not in clusters:
        clusters[row.Cluster] = {row.Crop: 1}
    else:
        cluster = clusters[row.Cluster]
        if row.Crop in cluster:
            cluster[row.Crop] += 1
        else:
            cluster[row.Crop] = 1
final_clusters = {}
for cluster in clusters:
    final_clusters[cluster] = []
    for crop in clusters[cluster]:
        if clusters[cluster][crop] > 50:
            final_clusters[cluster].append(crop)
print(final_clusters)
print(clusters)
# Out:
# {5: ['Rice', 'Papaya', 'Jute'], 0: ['Maize', 'Banana', 'Cotton', 'Coffee'], 1: ['MothBeans', 'MungBean', 'Blackgram', 'Lentil'], 6: ['ChickPea', 'KidneyBeans'], 4: ['PigeonPeas', 'Mango'], 3: ['Pomegranate', 'Orange', 'Coconut'], 2: ['Grapes', 'Apple'], 7: ['Watermelon', 'Muskmelon']}
# {5: {'Rice': 100, 'PigeonPeas': 1, 'Papaya': 56, 'Jute': 96, 'Coffee': 36}, 0: {'Maize': 99, 'Banana': 100, 'Papaya': 5, 'Cotton': 100, 'Jute': 4, 'Coffee': 64}, 1: {'Maize': 1, 'PigeonPeas': 1, 'MothBeans': 53, 'MungBean': 100, 'Blackgram': 100, 'Lentil': 100, 'Papaya': 36}, 6: {'ChickPea': 100, 'KidneyBeans': 100, 'PigeonPeas': 8}, 4: {'PigeonPeas': 90, 'MothBeans': 47, 'Mango': 100}, 3: {'Pomegranate': 100, 'Orange': 100, 'Papaya': 2, 'Coconut': 100}, 2: {'Grapes': 100, 'Apple': 100}, 7: {'Watermelon': 100, 'Muskmelon': 100, 'Papaya': 1}}

# %%
import numpy as np
count = 0
for k in np.arange(6,12):
    
    fig, ax = plt.subplots(figsize=(15,8))
    
    c = KMeans(n_clusters=k, random_state=0).fit_predict(X)
    silhouette_avg = silhouette_score(X, c)
    sample_silhouette_values = silhouette_samples(X, c)
    
    y_lower=10
    for i in range(k):
        ith_cluster_silhouette_values = sample_silhouette_values[c == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / k)
        ax.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )
        ax.text(-0.03, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
        
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax.set_xlabel('Silhouette Score')
    ax.set_ylabel('Cluster')
    ax.set_title('Silhouette Plot for ' + str(k) + ' Clusters')
    
    ax.set_yticks([])
    
    count += 1

# %%
W = []
cluster_range = list(range(5,22))

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0).fit(X_transformed)
    W.append(kmeans.inertia_)
    
fig, ax = plt.subplots()
ax.plot(cluster_range, W, '-*')
ax.set_xlabel('Number of Clusters')
ax.set_ylabel('Within Cluster Sum-of-Squares')
ax.set_title('Elbow Plot')
# Out:
# Text(0.5, 1.0, 'Elbow Plot')
