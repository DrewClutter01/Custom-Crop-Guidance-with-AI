# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Crop_Recommendation.csv')

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2200 non-null   int64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   pH_Value     2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
# the data types seem to be correct

# %%
df['Crop'].value_counts()
# Out:
# Blackgram      100
# Cotton         100
# Apple          100
# Mango          100
# Orange         100
# Grapes         100
# Muskmelon      100
# MungBean       100
# Coffee         100
# ChickPea       100
# PigeonPeas     100
# Jute           100
# Rice           100
# Coconut        100
# Maize          100
# MothBeans      100
# Pomegranate    100
# Papaya         100
# Banana         100
# Lentil         100
# KidneyBeans    100
# Watermelon     100
# Name: Crop, dtype: int64

# %%
df['pH_Value'].mean()
# Out:
# 6.469480065256364

# %%
df["Rainfall"].mean()
# Out:
# 103.46365541576817

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df_muskmelon = df[df['Crop'] == 'Muskmelon']

# %%
df_muskmelon.describe()
# Out:
#          Nitrogen  Phosphorus   Potassium  Temperature    Humidity  \
# count  100.000000  100.000000  100.000000   100.000000  100.000000
# mean   100.320000   17.720000   50.080000    28.663066   92.342802
# std     12.176215    7.187363    3.218256     0.861295    1.505117
# min     80.000000    5.000000   45.000000    27.024151   90.015064
# 25%     89.000000   12.000000   47.000000    27.959328   90.962363
# 50%    100.000000   18.000000   50.000000    28.851775   92.111116
# 75%    111.000000   25.000000   52.250000    29.370038   93.793552
# max    120.000000   30.000000   55.000000    29.943492   94.962187
#
#          pH_Value    Rainfall
# count  100.000000  100.000000
# mean     6.358805   24.689952
# std      0.231523    2.773999
# min      6.002927   20.211267
# 25%      6.155965   22.067976
# 50%      6.353033   24.721512
# 75%      6.550222   26.861601
# max      6.781050   29.866814

# %%
df_blackgram    = df[df['Crop'] == 'Blackgram']

# %%
df_blackgram.describe()
# Out:
#          Nitrogen  Phosphorus   Potassium  Temperature    Humidity  \
# count  100.000000  100.000000  100.000000   100.000000  100.000000
# mean    40.020000   67.470000   19.240000    29.973340   65.118426
# std     12.664258    7.151259    3.188109     2.686357    2.798326
# min     20.000000   55.000000   15.000000    25.097374   60.065349
# 25%     28.750000   62.000000   16.750000    27.822763   63.040532
# 50%     41.000000   67.000000   19.000000    29.655515   65.026723
# 75%     52.000000   74.000000   22.000000    32.379701   67.741171
# max     60.000000   80.000000   25.000000    34.946616   69.961000
#
#          pH_Value    Rainfall
# count  100.000000  100.000000
# mean     7.133952   67.884151
# std      0.372533    4.184186
# min      6.500145   60.417903
# 25%      6.812736   64.049755
# 50%      7.165240   68.293539
# 75%      7.419390   71.397924
# max      7.775306   74.915595

# %%
df.hist(bins = 15, figsize=(15,10), layout=(3,3))
plt.suptitle("Histograms of Numerical Features for Crops")
plt.show()

# %%
features = ['Nitrogen', 'Phosphorus', 'Potassium']
#, 'Temperature', 'Humidity', 'pH_Value', 'Rainfall'
for feature in features:
    plt.figure(figsize = (15,20))
    sns.boxplot(x='Crop', y=feature, data=df)
    plt.xticks(rotation = 45, ha='right')
    plt.tight_layout()

# %%
df_Blackgram = df[df['Crop'] == 'Blackgram']

# %%
df_Blackgram.describe()
# Out:
#          Nitrogen  Phosphorus   Potassium  Temperature    Humidity  \
# count  100.000000  100.000000  100.000000   100.000000  100.000000
# mean    40.020000   67.470000   19.240000    29.973340   65.118426
# std     12.664258    7.151259    3.188109     2.686357    2.798326
# min     20.000000   55.000000   15.000000    25.097374   60.065349
# 25%     28.750000   62.000000   16.750000    27.822763   63.040532
# 50%     41.000000   67.000000   19.000000    29.655515   65.026723
# 75%     52.000000   74.000000   22.000000    32.379701   67.741171
# max     60.000000   80.000000   25.000000    34.946616   69.961000
#
#          pH_Value    Rainfall
# count  100.000000  100.000000
# mean     7.133952   67.884151
# std      0.372533    4.184186
# min      6.500145   60.417903
# 25%      6.812736   64.049755
# 50%      7.165240   68.293539
# 75%      7.419390   71.397924
# max      7.775306   74.915595

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data=df_Blackgram, x="Te", y="Humidity", hue="pH_Value" )
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Humidity'>

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data=df_Blackgram, x="Nitrogen", y="Phosphorus", hue="pH_Value" )
# Out:
# <AxesSubplot:xlabel='Nitrogen', ylabel='Phosphorus'>

# %%
df_Blackgram = df[df['Crop'] == 'Blackgram']
